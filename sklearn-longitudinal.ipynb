# %%
# !pip uninstall scikit-learn -y
# !pip install scikit-longitudinal
# Out:
# Found existing installation: scikit-learn 1.8.0
# Uninstalling scikit-learn-1.8.0:
#   Successfully uninstalled scikit-learn-1.8.0
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\luis_\AppData\Local\Programs\Python\Python312\Lib\site-packages\~klearn'.
# You can safely remove it manually.
# ...
#   Using cached scikit_longitudinal-0.1.10-py3-none-any.whl.metadata (7.8 kB)
# ...
#   Using cached jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# ...
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached statsmodels-0.14.6-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# ...
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# ...
#   Using cached graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached liac-arff-2.5.0.tar.gz (13 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
# ...

# %%
from scikit_longitudinal.data_preparation import LongitudinalDataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from scikit_longitudinal.data_preparation import LongitudinalDataset
#
# ModuleNotFoundError: No module named 'scikit_longitudinal'

# %%
dataset = LongitudinalDataset("./database/hee_brazil_ambato_peru_base.csv")
dataset.load_data()
custom_names = [
    ['NUMBEROFLYMPHNODEEXCISION', 'NUMBEROFPOSITIVELYMPHNODEEXCISION', 'LN RATIO', 'SIZEOFPOSITIVELYMPHNODE(cm)'],
    [ 'RAI', 'RAIDOSE', 'TG PRE RAI']
    ]
dataset.setup_features_group(custom_names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 dataset = LongitudinalDataset("./database/hee_brazil_ambato_peru_base.csv")
#       2 dataset.load_data()
#       3 custom_names = [
#       4     ['NUMBEROFLYMPHNODEEXCISION', 'NUMBEROFPOSITIVELYMPHNODEEXCISION', 'LN RATIO', 'SIZEOFPOSITIVELYMPHNODE(cm)'],
#
# NameError: name 'LongitudinalDataset' is not defined
